# %%
import cv2

# %%
# path
path = '/content/3digits.png'
# path = '/content/4digits.png'
# path = '/content/5digits.png'

# Reading an image in default mode
# image = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
image = cv2.imread(path)
image
# Out:
# array([[[121, 118, 135],
#         [126, 123, 139],
#         [123, 117, 120],
#         ...,
#         [226, 202, 187],
#         [220, 194, 196],
#         [210, 184, 186]],
#
#        [[ 94,  98, 115],
#         [107, 110, 128],
#         [125, 130, 129],
#         ...,
#         [216, 197, 186],
#         [216, 195, 203],
#         [212, 191, 199]],
#
#        [[ 95, 101, 123],
#         [103, 109, 131],
#         [121, 123, 129],
#         ...,
#         [211, 199, 187],
#         [208, 196, 198],
#         [204, 192, 194]],
#
#        ...,
#
#        [[ 83, 102, 106],
#         [ 78,  98, 101],
#         [ 83, 104, 110],
#         ...,
#         [120, 131, 134],
#         [128, 127, 141],
#         [131, 131, 145]],
#
#        [[ 68,  91,  92],
#         [ 81, 104, 104],
#         [ 78,  97, 103],
#         ...,
#         [137, 134, 144],
#         [137, 134, 144],
#         [140, 136, 146]],
#
#        [[ 70,  89,  95],
#         [ 87, 105, 111],
#         [ 85, 101, 108],
# ...

# %%
num = 3

path = '/content/' + str(num) + 'digits.png'

image = cv2.imread(path)
y_end, x_end,c = image.shape
top = 58
bottom = 174
right = 470
thick = 70


for i in range(num):
  cropped = image[top:bottom,right-thick*(i+1):right-thick*i]
  output = '/content/' + str(num) + '_' + str(i) + '.png'
  cv2.imwrite(output, cropped)

# %%
num = 3

path = '/content/' + str(num) + 'digits.png'
# path = '/content/3digits.png'
# path = '/content/4digits.png'
# path = '/content/5digits.png'

# Reading an image in default mode
# image = cv2.imread(path,cv2.IMREAD_GRAYSCALE)
image = cv2.imread(path)
y_end, x_end,c = image.shape
top = 58
bottom = 174
right = 470
thick = 70


# # For drawing line to test
# color = (255, 0, 0) # RGB
# thickness = 1

# Standard
# image = cv2.line(image, (0,top), (x_end,top), color, thickness)
# image = cv2.line(image, (0,bottom), (x_end,bottom), color, thickness)
# image = cv2.line(image, (right,0), (right,y_end), color, thickness)

# each line for extracting number
# for i in range(1,num+1):
#   image = cv2.line(image, (right-thick*i,0), (right-thick*i,y_end), color, thickness)
# image

for i in range(num):
  cropped = image[top:bottom,right-thick*(i+1):right-thick*i]
  output = '/content/' + str(num) + '_' + str(i) + '.png'
  cv2.imwrite(output, cropped)

# cropped = image[top:bottom,right-thick:right]
# cropped

# %% [markdown]
# ## change shape to 224x224

# %%
import cv2

image = cv2.imread('/content/3digits_10_1.png')

image.shape
# Out:
# (116, 70, 3)

# %%
image
# Out:
# array([[[215, 212, 167],
#         [219, 216, 171],
#         [217, 210, 163],
#         ...,
#         [176, 169, 131],
#         [173, 166, 126],
#         [182, 175, 135]],
#
#        [[147, 145, 111],
#         [144, 141, 108],
#         [145, 140, 102],
#         ...,
#         [143, 132, 104],
#         [146, 137, 104],
#         [143, 133, 101]],
#
#        [[148, 141, 115],
#         [143, 136, 110],
#         [121, 115,  86],
#         ...,
#         [140, 124, 104],
#         [146, 131, 108],
#         [166, 151, 128]],
#
#        ...,
#
#        [[ 88,  66,  35],
#         [ 90,  68,  38],
#         [ 97,  77,  49],
#         ...,
#         [ 91,  82,  42],
#         [ 95,  79,  59],
#         [ 90,  74,  54]],
#
#        [[ 86,  66,  33],
#         [ 90,  69,  36],
#         [ 84,  71,  43],
#         ...,
#         [ 55,  46,  13],
#         [ 63,  48,  37],
#         [ 71,  56,  45]],
#
#        [[ 79,  64,  35],
#         [ 87,  72,  43],
#         [ 82,  71,  43],
# ...

# %%
resized_image = cv2.resize(image, (140, 224)) # (x,y) * 1.93...
resized_image
# Out:
# array([[[215, 212, 167],
#         [216, 213, 168],
#         [218, 215, 170],
#         ...,
#         [175, 168, 128],
#         [180, 173, 133],
#         [182, 175, 135]],
#
#        [[196, 193, 151],
#         [196, 194, 152],
#         [198, 195, 153],
#         ...,
#         [167, 159, 121],
#         [170, 162, 124],
#         [171, 163, 125]],
#
#        [[161, 159, 122],
#         [160, 158, 122],
#         [160, 157, 121],
#         ...,
#         [151, 143, 108],
#         [151, 142, 108],
#         [151, 141, 108]],
#
#        ...,
#
#        [[ 84,  65,  33],
#         [ 86,  67,  34],
#         [ 88,  68,  36],
#         ...,
#         [ 68,  52,  43],
#         [ 71,  55,  47],
#         [ 72,  57,  48]],
#
#        [[ 81,  65,  34],
#         [ 83,  66,  36],
#         [ 86,  69,  39],
#         ...,
#         [ 74,  59,  56],
#         [ 75,  60,  57],
#         [ 76,  60,  57]],
#
#        [[ 79,  64,  35],
#         [ 81,  66,  37],
#         [ 85,  70,  41],
# ...

# %%
resized_image = cv2.resize(image, (224, 224)) # (x,y) * 1.93...
resized_image
# Out:
# array([[[215, 212, 167],
#         [215, 212, 167],
#         [216, 213, 168],
#         ...,
#         [179, 172, 132],
#         [182, 175, 135],
#         [182, 175, 135]],
#
#        [[196, 193, 151],
#         [196, 193, 151],
#         [197, 194, 152],
#         ...,
#         [170, 162, 124],
#         [171, 163, 125],
#         [171, 163, 125]],
#
#        [[161, 159, 122],
#         [161, 159, 122],
#         [160, 158, 122],
#         ...,
#         [151, 142, 108],
#         [151, 141, 108],
#         [151, 141, 108]],
#
#        ...,
#
#        [[ 84,  65,  33],
#         [ 84,  65,  33],
#         [ 86,  67,  34],
#         ...,
#         [ 71,  55,  46],
#         [ 72,  57,  48],
#         [ 72,  57,  48]],
#
#        [[ 81,  65,  34],
#         [ 81,  65,  34],
#         [ 83,  66,  36],
#         ...,
#         [ 75,  60,  57],
#         [ 76,  60,  57],
#         [ 76,  60,  57]],
#
#        [[ 79,  64,  35],
#         [ 79,  64,  35],
#         [ 81,  66,  37],
# ...

# %%
resized_image = cv2.resize(image, (140, 224)) # (x,y) * 1.93...
resized_image
